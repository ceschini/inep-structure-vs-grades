# %% [markdown]
# # Preprocessing School grades dataset

# %% [markdown]
# Here we will preprocess the school grades dataset present in ```./data/ideb_ensino_media_escolas_2021```

# %%
import json
import missingno
import matplotlib
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# notebook only
# %matplotlib inline

# %%
df = pd.read_csv('./data/ideb_ensino_medio_escolas_2021.csv')

# %%
df.head()
# Out:
#   SG_UF  CO_MUNICIPIO           NO_MUNICIPIO  ID_ESCOLA
# 0    RO       1100015  Alta Floresta D'Oeste   11024682  \
# 1    RO       1100015  Alta Floresta D'Oeste   11024968
# 2    RO       1100015  Alta Floresta D'Oeste   11025638
# 3    RO       1100023              Ariquemes   11006773
# 4    RO       1100023              Ariquemes   11006889
#
#                                           NO_ESCOLA      REDE
# 0                      EEEFM EURIDICE LOPES PEDROSO  Estadual  \
# 1           EEEMTI JUSCELINO KUBITSCHEK DE OLIVEIRA  Estadual
# 2  COLEGIO TIRADENTES DA POLICIA MILITAR NA CTPM XI  Estadual
# 3                               EEEFM CORA CORALINA  Estadual
# 4                             EEEFM ANISIO TEIXEIRA  Estadual
#
#    VL_APROVACAO_2021_SI_4  VL_APROVACAO_2021_1  VL_APROVACAO_2021_2
# 0                    90.8                 89.3                 86.3  \
# 1                    98.9                 98.6                 98.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19836 entries, 0 to 19835
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SG_UF                   19836 non-null  object
#  1   CO_MUNICIPIO            19836 non-null  int64
#  2   NO_MUNICIPIO            19836 non-null  object
#  3   ID_ESCOLA               19836 non-null  int64
#  4   NO_ESCOLA               19836 non-null  object
#  5   REDE                    19836 non-null  object
#  6   VL_APROVACAO_2021_SI_4  18022 non-null  float64
#  7   VL_APROVACAO_2021_1     17919 non-null  float64
#  8   VL_APROVACAO_2021_2     17899 non-null  float64
#  9   TAXA_APROVACAO_3        18020 non-null  float64
#  10  VL_APROVACAO_2021_4     663 non-null    float64
#  11  INDICADOR_REND_P        18021 non-null  float64
#  12  SAEB_MAT                7196 non-null   float64
#  13  SAEB_PORTUGUES          7196 non-null   float64
# ...

# %%
df.describe()
# Out:
#        CO_MUNICIPIO     ID_ESCOLA  VL_APROVACAO_2021_SI_4
# count  1.983600e+04  1.983600e+04            18022.000000  \
# mean   3.250009e+06  3.247224e+07               91.070775
# std    9.596903e+05  9.570837e+06               10.170695
# min    1.100015e+06  1.100026e+07                0.000000
# 25%    2.609006e+06  2.609317e+07               87.000000
# 50%    3.301702e+06  3.303018e+07               94.500000
# 75%    3.557105e+06  3.592595e+07               98.700000
# max    5.300108e+06  5.306818e+07              100.000000
#
#        VL_APROVACAO_2021_1  VL_APROVACAO_2021_2  TAXA_APROVACAO_3
# count         17919.000000         17899.000000      18020.000000  \
# mean             91.429148            89.752964         92.530228
# std              10.458732            11.954284          9.973389
# min               0.000000             0.000000          0.000000
# 25%              87.300000            84.700000         89.075000
# ...
